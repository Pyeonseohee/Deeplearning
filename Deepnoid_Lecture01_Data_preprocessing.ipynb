# %% [markdown]
# <a href="https://colab.research.google.com/github/Pyeonseohee/Deeplearning/blob/main/Deepnoid_Lecture01_Data_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Load a color image in grayscale
import cv2
import matplotlib.pyplot as plt
from google.colab import files
image=cv2.imread('black.jpg')
plt.imshow(image)

# %%
import cv2

image=cv2.imread("Image/sad,jpg")
print(image)
# Out:
# None

# %%
import matplotlib.pyplot as plt
import cv2
from google.colab import files

image=cv2.imread('black.jpg')
height, width, channel = image.shape
matrix = cv2.getRotationMatrix2D((width/2, height/2), 90, 1)
dst = cv2.warpAffine(image, matrix, (width, height))

plt.imshow(image)
plt.imshow(dst)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import matplotlib.pyplot as plt
import cv2
from google.colab import files

image=cv2.imread('black.jpg')
dst = cv2.flip(image, 0)

plt.imshow(image)
plt.imshow(dst)
cv2.waitKey(0)
cv2.destroyAllWindows()
